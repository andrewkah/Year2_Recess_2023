# %%
from bs4 import BeautifulSoup
import requests
import csv
import json

# %%
# Bird species
url = 'https://xeno-canto.org/api/2/recordings'
response = requests.get(url)
# Bird Species with duplicates
if response.status_code == 200:
    data = response.json()
    if "recordings" in data:
        species_list = [recording["sp"] for recording in data["recordings"]]
        print(species_list)
else:
    print("Error: Unable to fetch data.")
        
# Bird Species With no Duplicates. 
if response.status_code == 200:
    data1 = response.json()
    if "recordings" in data1:
        species_list = list({recording["sp"] for recording in data1["recordings"]})
        print(species_list)
else:
    print("Error: Unable to fetch data.")  

# Bird species without duplicates into a CSV file
if response.status_code == 200:
    data2 = response.json()
    if "recordings" in data2:
        species_list = list({recording["sp"] for recording in data2["recordings"]})

        # Specify the file path for the CSV file
        csv_file_path = "species.csv"

        # Write the species_list to the CSV file
        with open(csv_file_path, "w", newline="", encoding="utf-8") as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow(["Species"])  # Write header row
            writer.writerows([[species] for species in species_list])  # Write species names row by row

        print("Data saved to CSV file successfully.")
else:
    print("Error: Unable to fetch data.")
# Out:
# Error: Unable to fetch data.
# Error: Unable to fetch data.
# Error: Unable to fetch data.

# %%
# Getting the audio list and species.
audio_list = []

species_list = []
for i in range(10):
    request_result = requests.get(url.format(str(i)))
    soup = BeautifulSoup(request_result.text, "html.parser")
    links = soup.find_all("audio")
    for link in links:
        audio_list.append("https:" + link.attrs["src"])
    names = soup.find_all("span", class_="common-name")
    for name in names:
        speciesData = name.find("a")
        species_list.append(
            {"species": speciesData.text, "species_link": speciesData.attrs["href"]}
        )

# Dumping them into a json file.
with open("bird_songs.json", "+a") as file:
    json.dump({"bird_songs": audio_list, "bird_species": species_list}, file)
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_11632\3637623489.py:7: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(request_result.text, "html.parser")

# %%
# Api query parameters(0).
sample = requests.get("https://xeno-canto.org/api/2/recordings?query=troglodytes+troglodytes")

print(sample.json())
# Out:
# {'numRecordings': '4091', 'numSpecies': '1', 'page': 1, 'numPages': 9, 'recordings': [{'id': '819361', 'gen': 'Troglodytes', 'sp': 'troglodytes', 'ssp': '', 'group': 'birds', 'en': 'Eurasian Wren', 'rec': 'Ingemar Gard', 'cnt': 'Sweden', 'loc': 'Aftonvägen, Tullinge, Stockholm', 'lat': '59.2037', 'lng': '17.9116', 'alt': '60', 'type': 'alarm call', 'sex': '', 'stage': '', 'method': 'field recording', 'url': '//xeno-canto.org/819361', 'file': 'https://xeno-canto.org/819361/download', 'file-name': 'XC819361-gardsmyg-230728.wav', 'sono': {'small': '//xeno-canto.org/sounds/uploaded/JFSMPDFREO/ffts/XC819361-small.png', 'med': '//xeno-canto.org/sounds/uploaded/JFSMPDFREO/ffts/XC819361-med.png', 'large': '//xeno-canto.org/sounds/uploaded/JFSMPDFREO/ffts/XC819361-large.png', 'full': '//xeno-canto.org/sounds/uploaded/JFSMPDFREO/ffts/XC819361-full.png'}, 'osci': {'small': '//xeno-canto.org/sounds/uploaded/JFSMPDFREO/wave/XC819361-small.png', 'med': '//xeno-canto.org/sounds/uploaded/JFSMPDFREO/wave/XC819361-med.png', 'large': '//xeno-canto.org/sounds/uploaded/JFSMPDFREO/wave/XC819361-large.png'}, 'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/', 'q': 'A', 'length': '0:49', 'time': '11:30', 'date': '2023-07-28', 'uploaded': '2023-07-28', 'also': [], 'rmk': 'Amplified. Noise reduction.', 'bird-seen': 'yes', 'animal-seen': 'yes', 'playback-used': 'no', 'temp': '', 'regnr': '', 'auto': 'no', 'dvc': 'Mobile phone', 'mic': '', 'smp': '44100'}, {'id': '819082', 'gen': 'Troglodytes', 'sp': 'troglodytes', 'ssp': '', 'group': 'birds', 'en': 'Eurasian Wren', 'rec': 'Uku Paal', 'cnt': 'Estonia', 'loc': 'Aiaste, Kanepi Parish, Põlva maakond', 'lat': '58.0479', 'lng': '26.6471', 'alt': '190', 'type': 'song', 'sex': '', 'stage': '', 'method': 'field recording', 'url': '//xeno-canto.org/819082', 'file': 'https://xeno-canto.org/819082/download', 'file-name': 'XC819082-TROTRO-AIASTE-230716_5418.mp3', 'sono': {'small': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/ffts/XC819082-small.png', 'med': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/ffts/XC819082-med.png', 'large': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/ffts/XC819082-large.png', 'full': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/ffts/XC819082-full.png'}, 'osci': {'small': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/wave/XC819082-small.png', 'med': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/wave/XC819082-med.png', 'large': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/wave/XC819082-large.png'}, 'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/', 'q': 'A', 'length': '13:29', 'time': '06:00', 'date': '2023-07-16', 'uploaded': '2023-07-26', 'also': [], 'rmk': 'Same as XC819081. hpf', 'bird-seen': 'no', 'animal-seen': 'no', 'playback-used': 'no', 'temp': '', 'regnr': '', 'auto': 'no', 'dvc': 'Tascam Dr-100mk', 'mic': 'Telinga Pro-7', 'smp': '44100'}, {'id': '819081', 'gen': 'Troglodytes', 'sp': 'troglodytes', 'ssp': '', 'group': 'birds', 'en': 'Eurasian Wren', 'rec': 'Uku Paal', 'cnt': 'Estonia', 'loc': 'Aiaste, Kanepi Parish, Põlva maakond', 'lat': '58.0479', 'lng': '26.6471', 'alt': '190', 'type': 'song', 'sex': '', 'stage': '', 'method': 'field recording', 'url': '//xeno-canto.org/819081', 'file': 'https://xeno-canto.org/819081/download', 'file-name': 'XC819081-TROTRO-AIASTE-230716_5417.mp3', 'sono': {'small': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/ffts/XC819081-small.png', 'med': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/ffts/XC819081-med.png', 'large': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/ffts/XC819081-large.png', 'full': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/ffts/XC819081-full.png'}, 'osci': {'small': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/wave/XC819081-small.png', 'med': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/wave/XC819081-med.png', 'large': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/wave/XC819081-large.png'}, 'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/', 'q': 'A', 'length': '2:19', 'time': '06:00', 'date': '2023-07-16', 'uploaded':  ...
